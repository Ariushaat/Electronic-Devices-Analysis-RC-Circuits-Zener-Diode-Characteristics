# %%
import matplotlib.pyplot as plt

# Datos medidos - Diodo (directo e inverso)
Vd_directo = [0.408, 0.444, 0.527, 0.563, 0.646, 0.682, 0.703, 0.718, 0.739, 0.776]
Id_directo = [50, 100, 500, 1000, 5000, 10000, 15000, 20000, 30000, 50000]

Vd_inverso = [-10, -14.99, -19.99, -24.99, -29.99]
Id_inverso = [-1.019, -1.519, -2.019, -2.519, -3.19]

# Datos experimentales - Diodo (directo e inverso)
Vd_directo_exp = [0.45, 0.47, 0.55, 0.58, 0.65, 0.68, 0.7, 0.71, 0.73, 0.75]
Id_directo_exp = [50, 100, 500, 1000, 5000, 10000, 15000, 20000, 30000, 50000]

Vd_inverso_exp = [-10, -15, -20, -25, -30]
Id_inverso_exp = [0, 0, 0, 0, 0]

# Crear figura y ejes
plt.figure(figsize=(10, 10))

# Graficar directo medido - Diodo
plt.plot(Vd_directo, Id_directo, 'bo-', label="Directo Medido")

# Graficar inverso medido - Diodo
plt.plot(Vd_inverso, Id_inverso, 'ro-', label="Inverso Medido")

# Graficar directo experimental - Diodo
plt.plot(Vd_directo_exp, Id_directo_exp, 'go--', label="Directo Experimental")

# Graficar inverso experimental - Diodo
plt.plot(Vd_inverso_exp, Id_inverso_exp, 'mo--', label="Inverso Experimental")

# Configurar ejes y cuadrantes
plt.axhline(0, color='black', lw=0.8)  # Línea horizontal (eje X)
plt.axvline(0, color='black', lw=0.8)  # Línea vertical (eje Y)

# Etiquetas
plt.xlabel("Voltaje [V]")
plt.ylabel("Corriente [µA]")
plt.title("Curva Característica Diodo")

# Leyenda
plt.legend()

# Cuadrícula
plt.grid(True)

# Mostrar gráfica
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos medidos (directo e inverso Zener)
Vd_directo_zener = [0.294, 0.329, 0.412, 0.448, 0.532, 0.568, 0.588, 0.603, 0.624, 0.651]
Id_directo_zener = [50, 100, 500, 1000, 5000, 10000, 15000, 20000, 30000, 50000]

Vd_inverso_zener = [-5.48, -5.499, -5.54, -5.55, -5.6, -5.61, -5.62, -5.63, -5.64, -5.66]
Id_inverso_zener = [-50, -100, -500, -1000, -5000, -10000, -15000, -20000, -30000, -50000]

# Datos experimentales (directo e inverso Zener)
Vd_directo_zener_exp = [0.65, 0.67, 0.71, 0.73, 0.78, 0.8, 0.82, 0.83, 0.84, 0.86]
Id_directo_zener_exp = [50, 100, 500, 1000, 5000, 10000, 15000, 20000, 30000, 50000]

Vd_inverso_zener_exp = [-4.11, -4.39, -4.97, -5.15, -5.45, -5.51, -5.55, -5.57, -5.6, -5.67]
Id_inverso_zener_exp = [-50, -100, -500, -1000, -5000, -10000, -15000, -20000, -30000, -50000]

# Crear figura y ejes
plt.figure(figsize=(10, 10))

# Graficar directo medido Zener
plt.plot(Vd_directo_zener, Id_directo_zener, 'bo-', label="Directo Zener Medido")

# Graficar inverso medido Zener
plt.plot(Vd_inverso_zener, Id_inverso_zener, 'ro-', label="Inverso Zener Medido")

# Graficar directo experimental Zener
plt.plot(Vd_directo_zener_exp, Id_directo_zener_exp, 'go--', label="Directo Zener Experimental")

# Graficar inverso experimental Zener
plt.plot(Vd_inverso_zener_exp, Id_inverso_zener_exp, 'mo--', label="Inverso Zener Experimental")

# Configurar ejes y cuadrantes
plt.axhline(0, color='black', lw=0.8)  # Eje X
plt.axvline(0, color='black', lw=0.8)  # Eje Y

# Etiquetas
plt.xlabel("Voltaje [V]")
plt.ylabel("Corriente [µA]")
plt.title("Curva Característica Diodo Zener")

# Leyenda
plt.legend()

# Cuadrícula
plt.grid(True)

# Mostrar gráfica
plt.show()
